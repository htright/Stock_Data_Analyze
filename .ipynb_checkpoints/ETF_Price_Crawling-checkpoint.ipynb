# %%
# !pip install -U fake-useragent
# Out:
# Requirement already satisfied: fake-useragent in c:\users\g4560\anaconda3\lib\site-packages (0.1.11)

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\g4560\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: webencodings in c:\users\g4560\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\g4560\anaconda3\lib\site-packages (from html5lib) (1.15.0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
from fake_useragent import UserAgent

# %% [markdown]
# ## ETF 크롤링
# - TIGER 200 IT (139260)
# - TIGER 헬스케어 (143860)

# %%
# format 응용
code = '139260'
url = 'https://finance.naver.com/item/sise_day.nhn?code={}&page=2'.format(code)
print(url)
# Out:
# https://finance.naver.com/item/sise_day.nhn?code=139260&page=2

# %%
url = 'https://finance.naver.com/item/sise_day.nhn?code=139260'
headers = {'user-agent' : UserAgent().chrome} #UserAgent 숨기기
response = requests.get(url, headers = headers)
# doc = BeautifulSoup(response.text, 'html.parser') #이거 안됨
doc = BeautifulSoup(response.text, 'html5lib') #속도가 느림 / 정확 
doc.select
# Out:
# <bound method Tag.select of <html lang="ko"><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>네이버 금융</title>
#
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/newstock.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/layout.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/main.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/newstock2.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/newstock3.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/world.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <script language="JavaScript">
# function mouseOver(obj){
#   obj.style.backgroundColor="#f6f4e5";
# }
# function mouseOut(obj){
#   obj.style.backgroundColor="#ffffff";
# }
# </script>
# 				<h4 class="tlline2"><strong><span class="red03">일별</span>시세</strong></h4>
# 				<table cellspacing="0" class="type2">
# 				<tbody><tr>
# 				<th>날짜</th>
# 				<th>종가</th>
# 				<th>전일비</th>
# 				<th>시가</th>
# 				<th>고가</th>
# 				<th>저가</th>
# 				<th>거래량</th>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
# 				<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 				<td align="center"><span class="tah p10 gray03">2022.04.05</span></td>
# 				<td class="num"><span class="tah p11">33,560</span></td>
# 				<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				165
# 				</span>
# 			</td>
# 				<td class="num"><span class="tah p11">33,600</span></td>
# 				<td class="num"><span class="tah p11">33,725</span></td>
# 				<td class="num"><span class="tah p11">33,475</span></td>
# 				<td class="num"><span class="tah p11">93,675</span></td>
# 				</tr>
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.04.04</span></td>
# 					<td class="num"><span class="tah p11">33,395</span></td>
# 					<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				20
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,240</span></td>
# 					<td class="num"><span class="tah p11">33,460</span></td>
# 					<td class="num"><span class="tah p11">32,965</span></td>
# 					<td class="num"><span class="tah p11">84,085</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.04.01</span></td>
# 					<td class="num"><span class="tah p11">33,375</span></td>
# 					<td class="num">
# 				<img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				560
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,685</span></td>
# 					<td class="num"><span class="tah p11">33,685</span></td>
# 					<td class="num"><span class="tah p11">33,375</span></td>
# 					<td class="num"><span class="tah p11">69,916</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.31</span></td>
# 					<td class="num"><span class="tah p11">33,935</span></td>
# 					<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				195
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,690</span></td>
# 					<td class="num"><span class="tah p11">33,955</span></td>
# 					<td class="num"><span class="tah p11">33,600</span></td>
# 					<td class="num"><span class="tah p11">72,093</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.30</span></td>
# 					<td class="num"><span class="tah p11">33,740</span></td>
# 					<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				445
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,820</span></td>
# 					<td class="num"><span class="tah p11">33,940</span></td>
# 					<td class="num"><span class="tah p11">33,680</span></td>
# 					<td class="num"><span class="tah p11">131,249</span></td>
# 					</tr>
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				<tr>
# 				<td bgcolor="#e1e1e1" colspan="7" height="1"></td>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.29</span></td>
# 					<td class="num"><span class="tah p11">33,295</span></td>
# 					<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				250
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,290</span></td>
# 					<td class="num"><span class="tah p11">33,460</span></td>
# 					<td class="num"><span class="tah p11">33,105</span></td>
# 					<td class="num"><span class="tah p11">102,835</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.28</span></td>
# 					<td class="num"><span class="tah p11">33,045</span></td>
# 					<td class="num">
# 				<img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				135
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,070</span></td>
# 					<td class="num"><span class="tah p11">33,255</span></td>
# 					<td class="num"><span class="tah p11">32,855</span></td>
# 					<td class="num"><span class="tah p11">123,810</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.25</span></td>
# 					<td class="num"><span class="tah p11">33,180</span></td>
# 					<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				5
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,515</span></td>
# 					<td class="num"><span class="tah p11">33,515</span></td>
# 					<td class="num"><span class="tah p11">33,090</span></td>
# 					<td class="num"><span class="tah p11">77,223</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.24</span></td>
# 					<td class="num"><span class="tah p11">33,175</span></td>
# 					<td class="num">
# 				<img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				325
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,200</span></td>
# 					<td class="num"><span class="tah p11">33,265</span></td>
# 					<td class="num"><span class="tah p11">32,890</span></td>
# 					<td class="num"><span class="tah p11">114,076</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.23</span></td>
# 					<td class="num"><span class="tah p11">33,500</span></td>
# 					<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				235
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,445</span></td>
# 					<td class="num"><span class="tah p11">33,600</span></td>
# 					<td class="num"><span class="tah p11">33,220</span></td>
# 					<td class="num"><span class="tah p11">106,651</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				</tbody></table>
# 				<!--- 페이지 네비게이션 시작--->
# 				<table align="center" class="Nnavi" summary="페이지 네비게이션 리스트">
# 				<caption>페이지 네비게이션</caption>
# 				<tbody><tr>
#
#
#
#                 <td class="on">
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=1">1</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=2">2</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=3">3</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=4">4</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=5">5</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=6">6</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=7">7</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=8">8</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=9">9</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=10">10</a>
# 				</td>
#
#                 <td class="pgR">
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=11">
# 				다음<img alt="" border="0" height="5" src="https://ssl.pstatic.net/static/n/cmn/bu_pgarR.gif" width="3"/>
# 				</a>
# 				</td>
#
#                 <td class="pgRR">
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=271">맨뒤
# 				<img alt="" border="0" height="5" src="https://ssl.pstatic.net/static/n/cmn/bu_pgarRR.gif" width="8"/>
# 				</a>
# 				</td>
#
#
# 				</tr>
# 				</tbody></table>
# 				<!--- 페이지 네비게이션 끝--->
#
#
# </body></html>>

# %%
UserAgent().chrome
# Out:
# 'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1667.0 Safari/537.36'

# %%
headers = {'user-agent' : UserAgent().chrome} #UserAgent 숨기기

# %%
response
# Out:
# <Response [200]>

# %%
doc
# Out:
# <html lang="ko"><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>네이버 금융</title>
#
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/newstock.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/layout.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/main.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/newstock2.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/newstock3.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220328121333/css/world.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <script language="JavaScript">
# function mouseOver(obj){
#   obj.style.backgroundColor="#f6f4e5";
# }
# function mouseOut(obj){
#   obj.style.backgroundColor="#ffffff";
# }
# </script>
# 				<h4 class="tlline2"><strong><span class="red03">일별</span>시세</strong></h4>
# 				<table cellspacing="0" class="type2">
# 				<tbody><tr>
# 				<th>날짜</th>
# 				<th>종가</th>
# 				<th>전일비</th>
# 				<th>시가</th>
# 				<th>고가</th>
# 				<th>저가</th>
# 				<th>거래량</th>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
# 				<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 				<td align="center"><span class="tah p10 gray03">2022.04.05</span></td>
# 				<td class="num"><span class="tah p11">33,560</span></td>
# 				<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				165
# 				</span>
# 			</td>
# 				<td class="num"><span class="tah p11">33,600</span></td>
# 				<td class="num"><span class="tah p11">33,725</span></td>
# 				<td class="num"><span class="tah p11">33,475</span></td>
# 				<td class="num"><span class="tah p11">93,675</span></td>
# 				</tr>
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.04.04</span></td>
# 					<td class="num"><span class="tah p11">33,395</span></td>
# 					<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				20
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,240</span></td>
# 					<td class="num"><span class="tah p11">33,460</span></td>
# 					<td class="num"><span class="tah p11">32,965</span></td>
# 					<td class="num"><span class="tah p11">84,085</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.04.01</span></td>
# 					<td class="num"><span class="tah p11">33,375</span></td>
# 					<td class="num">
# 				<img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				560
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,685</span></td>
# 					<td class="num"><span class="tah p11">33,685</span></td>
# 					<td class="num"><span class="tah p11">33,375</span></td>
# 					<td class="num"><span class="tah p11">69,916</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.31</span></td>
# 					<td class="num"><span class="tah p11">33,935</span></td>
# 					<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				195
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,690</span></td>
# 					<td class="num"><span class="tah p11">33,955</span></td>
# 					<td class="num"><span class="tah p11">33,600</span></td>
# 					<td class="num"><span class="tah p11">72,093</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.30</span></td>
# 					<td class="num"><span class="tah p11">33,740</span></td>
# 					<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				445
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,820</span></td>
# 					<td class="num"><span class="tah p11">33,940</span></td>
# 					<td class="num"><span class="tah p11">33,680</span></td>
# 					<td class="num"><span class="tah p11">131,249</span></td>
# 					</tr>
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				<tr>
# 				<td bgcolor="#e1e1e1" colspan="7" height="1"></td>
# 				</tr>
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.29</span></td>
# 					<td class="num"><span class="tah p11">33,295</span></td>
# 					<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				250
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,290</span></td>
# 					<td class="num"><span class="tah p11">33,460</span></td>
# 					<td class="num"><span class="tah p11">33,105</span></td>
# 					<td class="num"><span class="tah p11">102,835</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.28</span></td>
# 					<td class="num"><span class="tah p11">33,045</span></td>
# 					<td class="num">
# 				<img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				135
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,070</span></td>
# 					<td class="num"><span class="tah p11">33,255</span></td>
# 					<td class="num"><span class="tah p11">32,855</span></td>
# 					<td class="num"><span class="tah p11">123,810</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.25</span></td>
# 					<td class="num"><span class="tah p11">33,180</span></td>
# 					<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				5
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,515</span></td>
# 					<td class="num"><span class="tah p11">33,515</span></td>
# 					<td class="num"><span class="tah p11">33,090</span></td>
# 					<td class="num"><span class="tah p11">77,223</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.24</span></td>
# 					<td class="num"><span class="tah p11">33,175</span></td>
# 					<td class="num">
# 				<img alt="하락" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" style="margin-right:4px;" width="7"/><span class="tah p11 nv01">
# 				325
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,200</span></td>
# 					<td class="num"><span class="tah p11">33,265</span></td>
# 					<td class="num"><span class="tah p11">32,890</span></td>
# 					<td class="num"><span class="tah p11">114,076</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
# 					<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
# 					<td align="center"><span class="tah p10 gray03">2022.03.23</span></td>
# 					<td class="num"><span class="tah p11">33,500</span></td>
# 					<td class="num">
# 				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
# 				235
# 				</span>
# 			</td>
# 					<td class="num"><span class="tah p11">33,445</span></td>
# 					<td class="num"><span class="tah p11">33,600</span></td>
# 					<td class="num"><span class="tah p11">33,220</span></td>
# 					<td class="num"><span class="tah p11">106,651</span></td>
# 					</tr>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				<tr>
# 				<td colspan="7" height="8"></td>
# 				</tr>
# 				</tbody></table>
# 				<!--- 페이지 네비게이션 시작--->
# 				<table align="center" class="Nnavi" summary="페이지 네비게이션 리스트">
# 				<caption>페이지 네비게이션</caption>
# 				<tbody><tr>
#
#
#
#                 <td class="on">
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=1">1</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=2">2</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=3">3</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=4">4</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=5">5</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=6">6</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=7">7</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=8">8</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=9">9</a>
# 				</td>
# <td>
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=10">10</a>
# 				</td>
#
#                 <td class="pgR">
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=11">
# 				다음<img alt="" border="0" height="5" src="https://ssl.pstatic.net/static/n/cmn/bu_pgarR.gif" width="3"/>
# 				</a>
# 				</td>
#
#                 <td class="pgRR">
# 				<a href="/item/sise_day.nhn?code=139260&amp;page=271">맨뒤
# 				<img alt="" border="0" height="5" src="https://ssl.pstatic.net/static/n/cmn/bu_pgarRR.gif" width="8"/>
# 				</a>
# 				</td>
#
#
# 				</tr>
# 				</tbody></table>
# 				<!--- 페이지 네비게이션 끝--->
#
#
# </body></html>

# %%
doc.select('body > table.type2 > tbody > tr:nth-child(1) > th:nth-child(1)')
# Out:
# [<th>날짜</th>]

# %%
doc.select('body > table.type2 > tbody > tr:nth-child(1) > th')
# Out:
# [<th>날짜</th>,
#  <th>종가</th>,
#  <th>전일비</th>,
#  <th>시가</th>,
#  <th>고가</th>,
#  <th>저가</th>,
#  <th>거래량</th>]

# %%
headers = [h.text for h in doc.select ('body > table.type2 > tbody > tr:nth-child(1) > th')]
headers
# Out:
# ['날짜', '종가', '전일비', '시가', '고가', '저가', '거래량']

# %%
doc.select('body > table.type2 > tbody > tr:nth-child(3)')
# Out:
# [<tr onmouseout="mouseOut(this)" onmouseover="mouseOver(this)">
#  				<td align="center"><span class="tah p10 gray03">2022.04.05</span></td>
#  				<td class="num"><span class="tah p11">33,560</span></td>
#  				<td class="num">
#  				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
#  				165
#  				</span>
#  			</td>
#  				<td class="num"><span class="tah p11">33,600</span></td>
#  				<td class="num"><span class="tah p11">33,725</span></td>
#  				<td class="num"><span class="tah p11">33,475</span></td>
#  				<td class="num"><span class="tah p11">93,675</span></td>
#  				</tr>]

# %%
doc.select('body > table.type2 > tbody > tr:nth-child(3)')[0].text #지저분하게 추출됨
# Out:
# '\n\t\t\t\t2022.04.05\n\t\t\t\t33,560\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t165\n\t\t\t\t\n\t\t\t\n\t\t\t\t33,600\n\t\t\t\t33,725\n\t\t\t\t33,475\n\t\t\t\t93,675\n\t\t\t\t'

# %%
doc.select('body > table.type2 > tbody > tr:nth-child(3) > td')
# Out:
# [<td align="center"><span class="tah p10 gray03">2022.04.05</span></td>,
#  <td class="num"><span class="tah p11">33,560</span></td>,
#  <td class="num">
#  				<img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
#  				165
#  				</span>
#  			</td>,
#  <td class="num"><span class="tah p11">33,600</span></td>,
#  <td class="num"><span class="tah p11">33,725</span></td>,
#  <td class="num"><span class="tah p11">33,475</span></td>,
#  <td class="num"><span class="tah p11">93,675</span></td>]

# %%
len(doc.select('body > table.type2 > tbody > tr:nth-child(3) > td') ) #7개 값이 제대로 추출됨
# Out:
# 7

# %%
doc.select('body > table.type2 > tbody > tr:nth-child(3) > td')[0].text
# Out:
# '2022.04.05'

# %%
doc.select('body > table.type2 > tbody > tr:nth-child(3) > td')[3].text
# Out:
# '33,600'

# %%
# 3번째부터 7번까지 / 11번째부터 15번째까지 크롤링 해야함

# %%
for i in range(3, 8):
        row = doc.select('body > table.type2 > tbody > tr:nth-child({}) > td '.format(i))
        contents.append([data.text.replace('\n', '').replace('\t','') for data in row])

# %%
for i in range(11, 16):
        row = doc.select('body > table.type2 > tbody > tr:nth-child({}) > td '.format(i))
        contents.append([data.text.replace('\n', '').replace('\t','') for data in row])

# %%
contents = []
for i in range(1, 11):
    url = 'https://finance.naver.com/item/sise_day.nhn?code=139260&page={}'.format(i)
    headers = { 'user-agent' :  UserAgent().chrome}
    response = requests.get(url, headers=headers)
    doc = BeautifulSoup(response.text, 'html5lib')  # 속도가 느림 / 정확
    headers = [h.text for h in doc.select('body > table.type2 > tbody > tr:nth-child(1) > th')]
    #3번째부터 7번째까지 / 11번째부터 15번째까지
    for i in range(3, 8):
        row = doc.select('body > table.type2 > tbody > tr:nth-child({}) > td '.format(i))
        contents.append([data.text.replace('\n', '').replace('\t','') for data in row])
    for i in range(11, 16):
        row = doc.select('body > table.type2 > tbody > tr:nth-child({}) > td '.format(i))
        contents.append([data.text.replace('\n', '').replace('\t','') for data in row])

# %%
etf_data = pd.DataFrame(contents, columns=headers)
etf_data.set_index('날짜', inplace=True)
etf_data.applymap(lambda x : int(x.replace(',','')))
# Out:
#                종가  전일비     시가     고가     저가     거래량
# 날짜
# 2022.04.05  33560  165  33600  33725  33475   93675
# 2022.04.04  33395   20  33240  33460  32965   84085
# 2022.04.01  33375  560  33685  33685  33375   69916
# 2022.03.31  33935  195  33690  33955  33600   72093
# 2022.03.30  33740  445  33820  33940  33680  131249
# ...           ...  ...    ...    ...    ...     ...
# 2021.11.15  35840  735  35460  35890  35460  184064
# 2021.11.12  35105  215  35030  35280  34925  190686
# 2021.11.11  34890   55  34675  34890  34350  176329
# 2021.11.10  34945  220  35005  35135  34780  166817
# 2021.11.09  35165    0  35165  35445  34985  172488
#
# [100 rows x 6 columns]
