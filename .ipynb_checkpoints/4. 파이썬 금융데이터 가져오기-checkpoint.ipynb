# %% [markdown]
# ## FinanceDataReader

# %% [markdown]
# - https://github.com/FinanceData/FinanceDataReader/wiki/Users-Guide

# %%
# !pip install finance-datareader
import FinanceDataReader as fdr
# Out:
# Requirement already satisfied: finance-datareader in c:\users\g4560\anaconda3\lib\site-packages (0.9.33)
# Requirement already satisfied: tqdm in c:\users\g4560\anaconda3\lib\site-packages (from finance-datareader) (4.62.3)
# Requirement already satisfied: requests>=2.3.0 in c:\users\g4560\anaconda3\lib\site-packages (from finance-datareader) (2.26.0)
# Requirement already satisfied: requests-file in c:\users\g4560\anaconda3\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\g4560\anaconda3\lib\site-packages (from finance-datareader) (1.4.1)
# Requirement already satisfied: lxml in c:\users\g4560\anaconda3\lib\site-packages (from finance-datareader) (4.6.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\g4560\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\g4560\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\g4560\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\g4560\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19.2->finance-datareader) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.26.7)
# Requirement already satisfied: colorama in c:\users\g4560\anaconda3\lib\site-packages (from tqdm->finance-datareader) (0.4.4)

# %%
pip install -U finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in c:\users\g4560\anaconda3\lib\site-packages (0.9.33)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests>=2.3.0 in c:\users\g4560\anaconda3\lib\site-packages (from finance-datareader) (2.26.0)
# Requirement already satisfied: tqdm in c:\users\g4560\anaconda3\lib\site-packages (from finance-datareader) (4.62.3)
# Requirement already satisfied: lxml in c:\users\g4560\anaconda3\lib\site-packages (from finance-datareader) (4.6.3)
# Requirement already satisfied: requests-file in c:\users\g4560\anaconda3\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\g4560\anaconda3\lib\site-packages (from finance-datareader) (1.4.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\g4560\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\g4560\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\g4560\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\g4560\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19.2->finance-datareader) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\g4560\anaconda3\lib\site-packages (from tqdm->finance-datareader) (0.4.4)

# %%
import json

# %% [markdown]
# - StockListing에 들어갈 수 있는 다양한 Market
#     - KRX ( KOSPI, KOSDAQ, KONDEX)
#     - NASDAQ, NYSE, S&P500

# %%
krx_data = fdr.StockListing('KRX')
krx_data
# Out:
#       Symbol  Market             Name                    Sector  \
# 0     060310  KOSDAQ               3S                  전자부품 제조업
# 1     095570   KOSPI           AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI            AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ           APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ            AP시스템             특수 목적용 기계 제조업
# ...      ...     ...              ...                       ...
# 7908  000545   KOSPI            흥국화재우                       NaN
# 7909  003280   KOSPI             흥아해운                    해상 운송업
# 7910  037440  KOSDAQ               희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7911  419890   KOSPI  히어로즈 단기채권ESG액티브                       NaN
# 7912  238490  KOSDAQ               힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 7908                             NaN         NaT         NaN
# 7909                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 7910                       설계 및 감리용역  2000-02-03         12월
# 7911                             NaN         NaT         NaN
# 7912  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#             Representative                       HomePage Region
# 0                      김세완           http://www.3sref.com  서울특별시
# 1                 박대현, 손삼달         http://www.ajnet.co.kr  서울특별시
# 2        채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                      정기로   http://www.apsholdings.co.kr    경기도
# 4                      김영주     http://www.apsystems.co.kr    경기도
# ...                    ...                            ...    ...
# 7908                   NaN                            NaN    NaN
# 7909                   이환구         http://www.heung-a.com  서울특별시
# 7910  정영균, 이목운, 허철호 (각자대표)          http://www.heerim.com  서울특별시
# 7911                   NaN                            NaN    NaN
# 7912                   김주환          http://www.hims.co.kr  인천광역시
#
# [7913 rows x 10 columns]

# %%
snp_data = fdr.StockListing('S&P500')
snp_data
# Out:
# C:\Users\G4560\anaconda3\lib\site-packages\FinanceDataReader\wikipedia\listing.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Symbol'] = df['Symbol'].str.replace('\.', '')
#     Symbol           Name                  Sector  \
# 0      MMM             3M             Industrials
# 1      AOS    A. O. Smith             Industrials
# 2      ABT         Abbott             Health Care
# 3     ABBV         AbbVie             Health Care
# 4     ABMD        Abiomed             Health Care
# ..     ...            ...                     ...
# 500    YUM    Yum! Brands  Consumer Discretionary
# 501   ZBRA          Zebra  Information Technology
# 502    ZBH  Zimmer Biomet             Health Care
# 503   ZION  Zions Bancorp              Financials
# 504    ZTS         Zoetis             Health Care
#
#                                Industry
# 0              Industrial Conglomerates
# 1                     Building Products
# 2                 Health Care Equipment
# 3                       Pharmaceuticals
# 4                 Health Care Equipment
# ..                                  ...
# 500                         Restaurants
# 501  Electronic Equipment & Instruments
# 502               Health Care Equipment
# 503                      Regional Banks
# 504                     Pharmaceuticals
#
# [505 rows x 4 columns]

# %%
krx_data.loc[krx_data.Name == 'NAVER']
# Out:
#       Symbol Market   Name                            Sector         Industry  \
# 1721  035420  KOSPI  NAVER  자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업  포털 서비스 및 온라인 광고
#
#      ListingDate SettleMonth Representative                  HomePage Region
# 1721  2008-11-28         12월            최수연  http://www.navercorp.com    경기도

# %%
naver_symbol = krx_data.loc[krx_data.Name == 'NAVER', ['Symbol']]
naver_symbol
# Out:
#       Symbol
# 1721  035420

# %%
naver_symbol = krx_data.loc[krx_data.Name == 'NAVER', ['Symbol']].values[0][0]
naver_symbol
# Out:
# '035420'

# %%
# krx_data에서 Name 칼럼의 값이 "naver"인 행의 Symbol칼럼 값을 가져오기
naver_symbol = krx_data.loc[krx_data.Name == 'NAVER', ['Symbol']].values[0][0]

# 2018년부터 2020년까지
naver_df = fdr.DataReader(naver_symbol, '2018', '2020')
naver_df
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2018-01-02  174447  177251  174247  177251   93587  0.017240
# 2018-01-03  175448  177051  173045  174447   84790 -0.015819
# 2018-01-04  176048  179653  174847  178853  130112  0.025257
# 2018-01-05  178852  183858  176249  181857  136811  0.016796
# 2018-01-08  183258  190869  181856  190269  196338  0.046256
# ...            ...     ...     ...     ...     ...       ...
# 2019-12-23  185000  185500  182000  184000  250256  0.002725
# 2019-12-24  184000  184000  179000  182000  193440 -0.010870
# 2019-12-26  181500  183000  179000  180500  173426 -0.008242
# 2019-12-27  182000  185000  179000  183500  323473  0.016620
# 2019-12-30  183500  190000  183500  186500  376541  0.016349
#
# [490 rows x 6 columns]

# %%
amzn_df = fdr.DataReader('AMZN', '2018','2020')
amzn_df
# Out:
#               Close     Open     High      Low     Volume  Change
# Date
# 2018-01-02  1189.01  1172.00  1190.00  1170.51  2690000.0  0.0167
# 2018-01-03  1204.20  1188.30  1205.49  1188.30  3110000.0  0.0128
# 2018-01-04  1209.59  1205.00  1215.87  1204.66  3020000.0  0.0045
# 2018-01-05  1229.14  1217.51  1229.14  1210.00  3540000.0  0.0162
# 2018-01-08  1246.87  1236.00  1253.08  1232.03  4280000.0  0.0144
# ...             ...      ...      ...      ...        ...     ...
# 2019-12-24  1789.21  1793.81  1795.57  1787.58   881340.0 -0.0021
# 2019-12-26  1868.77  1801.01  1870.46  1799.50  6020000.0  0.0445
# 2019-12-27  1869.80  1882.92  1901.40  1866.01  6190000.0  0.0006
# 2019-12-30  1846.89  1874.00  1884.00  1840.62  3680000.0 -0.0123
# 2019-12-31  1847.84  1842.00  1853.26  1832.23  2510000.0  0.0005
#
# [503 rows x 6 columns]

# %%
curr = fdr.DataReader('USD/KRW', '2000')
curr.head()
# Out:
# C:\Users\G4560\anaconda3\lib\site-packages\FinanceDataReader\data.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(more)
#               Close     Open     High      Low  Change
# Date
# 2000-01-03  1127.50  1128.50  1128.50  1127.50 -0.0070
# 2000-01-04  1122.50  1133.50  1133.50  1121.50 -0.0044
# 2000-01-05  1134.50  1126.50  1135.00  1124.50  0.0107
# 2000-01-06  1146.25  1137.25  1147.35  1132.75  0.0104
# 2000-01-07  1137.50  1152.50  1155.50  1136.50 -0.0076

# %%
fdr.StockListing('KRX')[['Name','Symbol']]
# Out:
#                  Name  Symbol
# 0                  3S  060310
# 1              AJ네트웍스  095570
# 2               AK홀딩스  006840
# 3              APS홀딩스  054620
# 4               AP시스템  265520
# ...               ...     ...
# 7908            흥국화재우  000545
# 7909             흥아해운  003280
# 7910               희림  037440
# 7911  히어로즈 단기채권ESG액티브  419890
# 7912               힘스  238490
#
# [7913 rows x 2 columns]

# %%
# key : 종목명 / value : symbol
dct = dict(fdr.StockListing('KRX')[['Name','Symbol']].values)
dct
# Out:
# {'3S': '060310',
#  'AJ네트웍스': '095570',
#  'AK홀딩스': '006840',
#  'APS홀딩스': '054620',
#  'AP시스템': '265520',
#  'AP위성': '211270',
#  'ARIRANG 200': '152100',
#  'ARIRANG 200동일가중': '295820',
#  'ARIRANG 200선물레버리지': '253150',
#  'ARIRANG 200선물인버스2X': '253160',
#  'ARIRANG ESG가치주액티브': '395750',
#  'ARIRANG ESG성장주액티브': '395760',
#  'ARIRANG ESG우수기업': '278420',
#  'ARIRANG KRX300': '292750',
#  'ARIRANG KRX300헬스케어': '309210',
#  'ARIRANG KS로우볼가중TR': '333940',
#  'ARIRANG KS로우사이즈가중TR': '333950',
#  'ARIRANG KS모멘텀가중TR': '333960',
#  'ARIRANG KS밸류가중TR': '333970',
#  'ARIRANG KS퀄리티가중TR': '333980',
#  'ARIRANG S&P글로벌인프라': '269530',
#  'ARIRANG iSelect우주항공&UAM': '421320',
#  'ARIRANG 고배당저변동50': '251590',
#  'ARIRANG 고배당주': '161510',
#  'ARIRANG 고배당주채권혼합': '251600',
#  'ARIRANG 국채선물10년': '289670',
#  'ARIRANG 국채선물3년': '298340',
#  'ARIRANG 글로벌MSCI(합성 H)': '189400',
#  'ARIRANG 글로벌수소&차세대연료전지MV': '419650',
#  'ARIRANG 글로벌희토류전략자원기업MV': '415920',
#  'ARIRANG 단기채권액티브': '278620',
#  'ARIRANG 미국S&P500(H)': '269540',
#  'ARIRANG 미국나스닥테크': '287180',
#  'ARIRANG 미국다우존스고배당주(합성 H)': '213630',
#  'ARIRANG 미국단기우량회사채': '332610',
#  'ARIRANG 미국장기우량회사채': '332620',
#  'ARIRANG 선진국MSCI(합성 H)': '195970',
#  'ARIRANG 스마트베타Quality채권혼합': '238670',
#  'ARIRANG 신흥국MSCI(합성 H)': '195980',
#  'ARIRANG 신흥국MSCI인버스(합성 H)': '373530',
#  'ARIRANG 심천차이넥스트(합성)': '256450',
#  'ARIRANG 우량회사채50 1년': '239660',
#  'ARIRANG 주도업종': '280920',
#  'ARIRANG 중형주저변동50': '266550',
#  'ARIRANG 코스닥150': '301400',
#  'ARIRANG 코스닥150선물인버스': '301410',
#  'ARIRANG 코스피': '227830',
#  'ARIRANG 코스피50': '122090',
#  'ARIRANG 코스피TR': '328370',
#  'ARIRANG 코스피중형주': '301440',
#  'ARIRANG 탄소효율그린뉴딜': '376250',
#  'BGF': '027410',
#  'BGF리테일': '282330',
#  'BNGT': '032790',
#  'BNK금융지주': '138930',
#  'BYC': '001460',
#  'BYC우': '001465',
#  'CBI': '013720',
#  'CJ': '001040',
#  'CJ CGV': '079160',
#  'CJ ENM': '035760',
#  'CJ 바이오사이언스': '311690',
#  'CJ4우(전환)': '00104K',
#  'CJ대한통운': '000120',
#  'CJ씨푸드': '011150',
#  'CJ씨푸드1우': '011155',
#  'CJ우': '001045',
#  'CJ제일제당': '097950',
#  'CJ제일제당 우': '097955',
#  'CJ프레시웨이': '051500',
#  'CMG제약': '058820',
#  'CNH': '023460',
#  'CNT85': '056730',
#  'COWON': '056000',
#  'CS': '065770',
#  'CSA 코스믹': '083660',
#  'CS홀딩스': '000590',
#  'DB': '012030',
#  'DB금융스팩10호': '404950',
#  'DB금융스팩8호': '367340',
#  'DB금융스팩9호': '367360',
#  'DB금융투자': '016610',
#  'DB손해보험': '005830',
#  'DB하이텍': '000990',
#  'DB하이텍1우': '000995',
#  'DGB금융지주': '139130',
#  'DI동일': '001530',
#  'DL': '000210',
#  'DL건설': '001880',
#  'DL우': '000215',
#  'DL이앤씨': '375500',
#  'DL이앤씨우': '37550K',
#  'DMS': '068790',
#  'DRB동일': '004840',
#  'DSC인베스트먼트': '241520',
#  'DSR': '155660',
#  'DSR제강': '069730',
#  'E1': '017940',
#  'EDGC': '245620',
#  'EG': '037370',
#  'EMB': '278990',
#  'EMW': '079190',
#  'ESR켄달스퀘어리츠': '365550',
#  'ES큐브': '050120',
#  'F&F': '383220',
#  'F&F홀딩스': '007700',
#  'FOCUS ESG리더스': '285690',
#  'FOCUS KRX300': '292730',
#  'FOCUS 혁신기업액티브': '402520',
#  'FSN': '214270',
#  'GB국민참여정책형뉴딜A': '73501BB4',
#  'GB국민참여정책형뉴딜C': '73502BB4',
#  'GB국민참여정책형뉴딜I': '73503BB4',
#  'GB뉴딜기업2호A': '73501BBC',
#  'GB뉴딜기업2호Ae': '73502BBC',
#  'GB중소성장기업A': '73501BA2',
#  'GB중소성장기업C': '73502BA2',
#  'GB중소성장기업I': '73503BA2',
#  'GH신소재': '130500',
#  'GKL': '114090',
#  'GRT': '900290',
#  'GS': '078930',
#  'GST': '083450',
#  'GS건설': '006360',
#  'GS글로벌': '001250',
#  'GS리테일': '007070',
#  'GS우': '078935',
#  'HANARO 200': '293180',
#  'HANARO 200 TOP10': '407310',
#  'HANARO 200TR': '332930',
#  'HANARO 200선물레버리지': '304780',
#  'HANARO 200선물인버스': '306520',
#  'HANARO Fn K-POP&미디어': '395290',
#  'HANARO Fn K-게임': '395280',
#  'HANARO Fn K-뉴딜디지털플러스': '368190',
#  'HANARO Fn K-메타버스MZ': '402460',
#  'HANARO Fn K-반도체': '395270',
#  'HANARO Fn5G산업': '367740',
#  'HANARO Fn골프테마': '407300',
#  'HANARO Fn전기&수소차': '381560',
#  'HANARO Fn친환경에너지': '381570',
#  'HANARO KAP초장기국고채': '346000',
#  'HANARO KRX300': '304760',
#  'HANARO KRX기후변화솔루션': '404470',
#  'HANARO MSCI Korea TR': '332940',
#  'HANARO e커머스': '322400',
#  'HANARO 고배당': '322410',
#  'HANARO 글로벌럭셔리S&P(합성)': '354350',
#  'HANARO 글로벌탄소배출권선물ICE(합성)': '401590',
#  'HANARO 농업융복합산업': '314700',
#  'HANARO 단기채권액티브': '390950',
#  'HANARO 미국메타버스iSelect': '419170',
#  'HANARO 코스닥150': '304770',
#  'HANARO 코스닥150선물레버리지': '306530',
#  'HANARO 탄소효율그린뉴딜': '375760',
#  'HB솔루션': '297890',
#  'HB테크놀러지': '078150',
#  'HDC': '012630',
#  'HDC랩스': '039570',
#  'HDC현대EP': '089470',
#  'HDC현대산업개발': '294870',
#  'HJ중공업': '097230',
#  'HK S&P코리아로우볼': '215620',
#  'HK 베스트일레븐액티브': '391670',
#  'HK 하이볼액티브': '391680',
#  'HK이노엔': '195940',
#  'HLB': '028300',
#  'HLB생명과학': '067630',
#  'HLB제약': '047920',
#  'HLB테라퓨틱스': '115450',
#  'HMM': '011200',
#  'HRS': '036640',
#  'HSD엔진': '082740',
#  'IBK 국민참여정책형뉴딜 혼합자산 A': '75801BB4',
#  'IBK 국민참여정책형뉴딜 혼합자산 C': '75802BB4',
#  'IBKS제12호스팩': '335870',
#  'IBKS제13호스팩': '351340',
#  'IBKS제16호스팩': '388790',
#  'IBKS제17호스팩': '405350',
#  'IBK국민참여정책형뉴딜혼합자산2호A': '75801BBC',
#  'IBK국민참여정책형뉴딜혼합자산2호C': '75802BBC',
#  'IHQ': '003560',
#  'ISC': '095340',
#  'ITX-AI': '099520',
#  'JB금융지주': '175330',
#  'JTC': '950170',
#  'JW생명과학': '234080',
#  'JW신약': '067290',
#  'JW중외제약': '001060',
#  'JW중외제약2우B': '001067',
#  'JW중외제약우': '001065',
#  'JW홀딩스': '096760',
#  'JYP Ent.': '035900',
#  'KB FnGuide 언택트 ETN': '580011',
#  'KB KOSDAQ 150 선물 ETN': '580030',
#  'KB KOSPI 200 선물 ETN': '580028',
#  'KB KRX ESG Eco ETN': '580013',
#  'KB S&P 유럽탄소배출권 선물 ETN(H)': '580035',
#  'KB Wise 분할매매 ETN': '580010',
#  'KB 레버리지 KRX 2차전지 K-뉴딜 ETN': '580025',
#  'KB 레버리지 KRX BBIG K-뉴딜 ETN': '580024',
#  'KB 레버리지 S&P 500 선물 ETN(H)': '580016',
#  'KB 레버리지 구리 선물 ETN(H)': '580032',
#  'KB 레버리지 금 선물 ETN(H)': '580022',
#  'KB 레버리지 나스닥 100 ETN': '580015',
#  'KB 레버리지 은 선물 ETN(H)': '580026',
#  'KB 레버리지 항셍테크 선물 ETN(H)': '580018',
#  'KB 와이즈 스타 부동산 자 2 A': '71901B96',
#  'KB 와이즈 스타 부동산 자 2 C-F': '71902B96',
#  'KB 와이즈 스타 부동산 자 2 C-I': '71903B96',
#  'KB 인버스 2X S&P 500 선물 ETN': '580017',
#  'KB 인버스 2X 구리 선물 ETN(H)': '580033',
#  'KBGT27KOSPI200풋': '58GT27',
#  'KBGT28KOSPI200풋': '58GT28',
#  'KBGT29KOSPI200풋': '58GT29',
#  'KBGT30KOSPI200풋': '58GT30',
#  'KBGT31KOSPI200풋': '58GT31',
#  'KBGT32KOSPI200풋': '58GT32',
#  'KBGT33KOSPI200풋': '58GT33',
#  'KBGT34KOSPI200풋': '58GT34',
#  'KBGT35KOSPI200풋': '58GT35',
#  'KBGT36KOSPI200풋': '58GT36',
#  'KBGT37KOSPI200풋': '58GT37',
#  'KBGT38KOSPI200풋': '58GT38',
#  'KBGT39KOSPI200풋': '58GT39',
#  'KBGT40KOSPI200풋': '58GT40',
#  'KBGT41KOSPI200풋': '58GT41',
#  'KBGT42KOSPI200풋': '58GT42',
#  'KBGT43KOSPI200풋': '58GT43',
#  'KBGT44KOSPI200풋': '58GT44',
#  'KBGT45KOSPI200풋': '58GT45',
#  'KBGT46엘지디스콜': '58GT46',
#  'KBGT47LG생건풋': '58GT47',
#  'KBGT48LG이노텍콜': '58GT48',
#  'KBGT49LG이노텍콜': '58GT49',
#  'KBGT50엘지전자콜': '58GT50',
#  'KBGT51엘지전자풋': '58GT51',
#  'KBGT52LG화학콜': '58GT52',
#  'KBGT53LG화학콜': '58GT53',
#  'KBGT55네이버콜': '58GT55',
#  'KBGT56네이버풋': '58GT56',
#  'KBGT57POSCO홀콜': '58GT57',
#  'KBGT58POSCO홀콜': '58GT58',
#  'KBGT59SK콜': '58GT59',
#  'KBGT60SK바이오콜': '58GT60',
#  'KBGT61SK아이이콜': '58GT61',
#  'KBGT62SK이노콜': '58GT62',
#  'KBGT63SK이노풋': '58GT63',
#  'KBGT65SK하이닉콜': '58GT65',
#  'KBGT66SK하이닉풋': '58GT66',
#  'KBGT67금호석유콜': '58GT67',
#  'KBGT69기아콜': '58GT69',
#  'KBGT70기아풋': '58GT70',
#  'KBGT72녹십자콜': '58GT72',
#  'KBGT73두산퓨얼콜': '58GT73',
#  'KBGT74두산퓨얼콜': '58GT74',
#  'KBGT75롯데케미콜': '58GT75',
#  'KBGT76롯데케미풋': '58GT76',
#  'KBGT77삼성SDI콜': '58GT77',
#  'KBGT78삼성SDI풋': '58GT78',
#  'KBGT79삼성물산콜': '58GT79',
#  'KBGT80삼성바이콜': '58GT80',
#  'KBGT82삼성바이풋': '58GT82',
#  'KBGT84삼성전기콜': '58GT84',
#  'KBGT85삼성전자콜': '58GT85',
#  'KBGT86삼성전자콜': '58GT86',
#  'KBGT87삼성전자콜': '58GT87',
#  'KBGT88삼성전자콜': '58GT88',
#  'KBGT89삼성전자콜': '58GT89',
#  'KBGT90삼성전자콜': '58GT90',
#  'KBGT91삼성전자풋': '58GT91',
#  'KBGT92신한지주콜': '58GT92',
#  'KBGT93신한지주풋': '58GT93',
#  'KBGT94신한지주콜': '58GT94',
#  'KBGT95아모레콜': '58GT95',
#  'KBGT96아모레콜': '58GT96',
#  'KBGT98SK바이팜콜': '58GT98',
#  'KBGW49KOSPI200풋': '58GW49',
#  'KBGW50KOSPI200풋': '58GW50',
#  'KBGW51KOSPI200풋': '58GW51',
#  'KBGW52KOSPI200풋': '58GW52',
#  'KBGW53KOSPI200풋': '58GW53',
#  'KBGW54KOSPI200콜': '58GW54',
#  'KBGW55KOSPI200콜': '58GW55',
#  'KBGW56KOSPI200콜': '58GW56',
#  'KBGW57KOSPI200콜': '58GW57',
#  'KBGW58KOSPI200콜': '58GW58',
#  'KBGW59KOSPI200콜': '58GW59',
#  'KBGW60KOSPI200콜': '58GW60',
#  'KBGW61KOSPI200콜': '58GW61',
#  'KBGW62KOSPI200콜': '58GW62',
#  'KBGW72KOSPI200콜': '58GW72',
#  'KBGW73KOSPI200콜': '58GW73',
#  'KBGW74KOSPI200콜': '58GW74',
#  'KBGW76KOSPI200콜': '58GW76',
#  'KBGW77KOSPI200콜': '58GW77',
#  'KBGW78KOSPI200풋': '58GW78',
#  'KBGW79KOSPI200풋': '58GW79',
#  'KBGW80KOSPI200풋': '58GW80',
#  'KBGW81KOSPI200콜': '58GW81',
#  'KBGW82KOSPI200콜': '58GW82',
#  'KBGW83KOSPI200콜': '58GW83',
#  'KBGW84KOSPI200콜': '58GW84',
#  'KBGW85KOSPI200콜': '58GW85',
#  'KBGW86KOSPI200풋': '58GW86',
#  'KBGW87KOSPI200풋': '58GW87',
#  'KBGW88KOSPI200풋': '58GW88',
#  'KBGW89KOSPI200콜': '58GW89',
#  'KBH001DB하이텍콜': '58H001',
#  'KBH002DB하이텍콜': '58H002',
#  'KBH005엘지디스풋': '58H005',
#  'KBH006LG생건콜': '58H006',
#  'KBH007LG이노텍콜': '58H007',
#  'KBH008LG이노텍풋': '58H008',
#  'KBH009엘지전자콜': '58H009',
#  'KBH010엘지전자콜': '58H010',
#  'KBH011엘지전자풋': '58H011',
#  'KBH013네이버콜': '58H013',
#  'KBH014네이버콜': '58H014',
#  'KBH015네이버콜': '58H015',
#  'KBH016네이버풋': '58H016',
#  'KBH017POSCO홀콜': '58H017',
#  'KBH018POSCO홀풋': '58H018',
#  'KBH020SK풋': '58H020',
#  'KBH021SK바이오콜': '58H021',
#  'KBH023SK스퀘어콜': '58H023',
#  'KBH024SK아이이콜': '58H024',
#  'KBH025SK이노콜': '58H025',
#  'KBH027SK하이닉콜': '58H027',
#  'KBH028SK하이닉콜': '58H028',
#  'KBH029SK하이닉콜': '58H029',
#  'KBH030SK하이닉풋': '58H030',
#  'KBH032두산중공콜': '58H032',
#  'KBH033삼성SDI풋': '58H033',
#  'KBH034삼성물산콜': '58H034',
#  'KBH036삼성바이풋': '58H036',
#  'KBH040삼성전자콜': '58H040',
#  'KBH041삼성전자콜': '58H041',
#  'KBH042삼성전자풋': '58H042',
#  'KBH052신한지주콜': '58H052',
#  'KBH054아모레콜': '58H054',
#  'KBH055아모레콜': '58H055',
#  'KBH056아모레풋': '58H056',
#  'KBH057NC소프트콜': '58H057',
#  'KBH058카카오콜': '58H058',
#  'KBH059카카오콜': '58H059',
#  'KBH060카카오콜': '58H060',
#  'KBH061카카오풋': '58H061',
#  'KBH065하나금융콜': '58H065',
#  'KBH067하이브콜': '58H067',
#  'KBH068하이브콜': '58H068',
#  'KBH069한국전력콜': '58H069',
#  'KBH070한화솔루콜': '58H070',
#  'KBH074현대차콜': '58H074',
#  'KBH075현대차풋': '58H075',
#  'KBH077현대상선콜': '58H077',
#  'KBH080LG생건콜': '58H080',
#  'KBH081LG이노텍콜': '58H081',
#  'KBH083LG화학콜': '58H083',
#  'KBH084네이버콜': '58H084',
#  'KBH085네이버콜': '58H085',
#  'KBH086네이버풋': '58H086',
#  'KBH088SK바이오콜': '58H088',
#  'KBH089SK스퀘어콜': '58H089',
#  'KBH090SK아이이콜': '58H090',
#  'KBH091SK하이닉콜': '58H091',
#  'KBH092SK하이닉콜': '58H092',
#  'KBH093기아콜': '58H093',
#  'KBH094두산중공콜': '58H094',
#  'KBH095삼성SDI콜': '58H095',
#  'KBH096삼성바이콜': '58H096',
#  'KBH097삼성전자콜': '58H097',
#  'KBH098삼성전자풋': '58H098',
#  'KBH106신한지주콜': '58H106',
#  'KBH109카카오콜': '58H109',
#  'KBH110카카오콜': '58H110',
#  'KBH113크래프톤콜': '58H113',
#  'KBH114포스코케콜': '58H114',
#  'KBH116하이브콜': '58H116',
#  'KBH117하이브콜': '58H117',
#  'KBH122네이버콜': '58H122',
#  'KBH123네이버콜': '58H123',
#  'KBH124SK이노콜': '58H124',
#  'KBH125SK하이닉콜': '58H125',
#  'KBH126SK하이닉콜': '58H126',
#  'KBH127SK하이닉풋': '58H127',
#  'KBH128기아콜': '58H128',
#  'KBH129삼성SDI콜': '58H129',
#  'KBH130삼성물산콜': '58H130',
#  'KBH132삼성전기콜': '58H132',
#  'KBH135삼성전자콜': '58H135',
#  'KBH139NC소프트콜': '58H139',
#  'KBH141카카오콜': '58H141',
#  'KBH142카카오풋': '58H142',
#  'KBH144크래프톤콜': '58H144',
#  'KBH145포스코케콜': '58H145',
#  'KBH147현대차콜': '58H147',
#  'KBH149엘지전자콜': '58H149',
#  'KBH150네이버콜': '58H150',
#  'KBH151POSCO홀콜': '58H151',
#  'KBH153SK하이닉콜': '58H153',
#  'KBH155삼성SDI콜': '58H155',
#  'KBH156삼성전자콜': '58H156',
#  'KBH157삼성전자풋': '58H157',
#  'KBH161카카오콜': '58H161',
#  'KBH163카카뱅크콜': '58H163',
#  'KBH166LG이노텍콜': '58H166',
#  'KBH167SK하이닉콜': '58H167',
#  'KBH168삼성전자콜': '58H168',
#  'KBH169삼성전자콜': '58H169',
#  'KBH172카카오콜': '58H172',
#  'KBH173카카오콜': '58H173',
#  'KBH174현대차콜': '58H174',
#  'KBH175삼성전자콜': '58H175',
#  'KBH176삼성전자풋': '58H176',
#  'KBH177삼성전자콜': '58H177',
#  'KBH178삼성전자콜': '58H178',
#  'KBH179삼성전자콜': '58H179',
#  'KBH180삼성전자콜': '58H180',
#  'KBH181KOSPI200콜': '58H181',
#  'KBH182KOSPI200콜': '58H182',
#  'KBH183KOSPI200콜': '58H183',
#  'KBH184KOSPI200콜': '58H184',
#  'KBH185KOSPI200콜': '58H185',
#  'KBH186KOSPI200콜': '58H186',
#  'KBH187KOSPI200콜': '58H187',
#  'KBH188KOSPI200콜': '58H188',
#  'KBH189KOSPI200콜': '58H189',
#  'KBH190KOSPI200콜': '58H190',
#  'KBH191KOSPI200콜': '58H191',
#  'KBH192KOSPI200콜': '58H192',
#  'KBH193KOSPI200콜': '58H193',
#  'KBH194KOSPI200콜': '58H194',
#  'KBH195KOSPI200콜': '58H195',
#  'KBH196KOSPI200콜': '58H196',
#  'KBH197KOSPI200콜': '58H197',
#  'KBH198KOSPI200콜': '58H198',
#  'KBH199KOSPI200콜': '58H199',
#  'KBH200KOSPI200풋': '58H200',
#  'KBH201KOSPI200풋': '58H201',
#  'KBH202KOSPI200풋': '58H202',
#  'KBH203KOSPI200풋': '58H203',
#  'KBH204KOSPI200풋': '58H204',
#  'KBH205KOSPI200풋': '58H205',
#  'KBH206KOSPI200풋': '58H206',
#  'KBH207KOSPI200풋': '58H207',
#  'KBH208KOSPI200풋': '58H208',
#  'KBH209KOSPI200풋': '58H209',
#  'KBH210KOSPI200풋': '58H210',
#  'KBH211KOSPI200콜': '58H211',
#  'KBH212KOSPI200콜': '58H212',
#  'KBH213KOSPI200콜': '58H213',
#  'KBH214KOSPI200콜': '58H214',
#  'KBH215KOSPI200콜': '58H215',
#  'KBH216KOSPI200콜': '58H216',
#  'KBH217KOSPI200콜': '58H217',
#  'KBH218KOSPI200콜': '58H218',
#  'KBH219KOSPI200콜': '58H219',
#  'KBH220KOSPI200콜': '58H220',
#  'KBH221KOSPI200풋': '58H221',
#  'KBH222KOSPI200풋': '58H222',
#  'KBH223KOSPI200풋': '58H223',
#  'KBH224KOSPI200풋': '58H224',
#  'KBH225KOSPI200풋': '58H225',
#  'KBH226KOSPI200콜': '58H226',
#  'KBH227KOSPI200콜': '58H227',
#  'KBH228KOSPI200콜': '58H228',
#  'KBH229KOSPI200콜': '58H229',
#  'KBH230KOSPI200콜': '58H230',
#  'KBH231KOSPI200콜': '58H231',
#  'KBH232KOSPI200콜': '58H232',
#  'KBH233KOSPI200콜': '58H233',
#  'KBH234KOSPI200콜': '58H234',
#  'KBH235KOSPI200콜': '58H235',
#  'KBH236KOSPI200콜': '58H236',
#  'KBH237KOSPI200콜': '58H237',
#  'KBH238KOSPI200콜': '58H238',
#  'KBH239KOSPI200콜': '58H239',
#  'KBH240KOSPI200콜': '58H240',
#  'KBH241KOSPI200콜': '58H241',
#  'KBH242KOSPI200콜': '58H242',
#  'KBH243KOSPI200콜': '58H243',
#  'KBH244KOSPI200콜': '58H244',
#  'KBH245DB하이텍콜': '58H245',
#  'KBH246DB하이텍풋': '58H246',
#  'KBH247엘지디스콜': '58H247',
#  'KBH248엘지디스풋': '58H248',
#  'KBH249LG생건콜': '58H249',
#  'KBH250LG이노텍콜': '58H250',
#  'KBH251엘지전자콜': '58H251',
#  'KBH252엘지전자풋': '58H252',
#  'KBH253LG화학콜': '58H253',
#  'KBH254LG화학콜': '58H254',
#  'KBH255LG화학풋': '58H255',
#  'KBH256네이버콜': '58H256',
#  'KBH257네이버풋': '58H257',
#  'KBH258POSCO홀콜': '58H258',
#  'KBH259POSCO홀풋': '58H259',
#  'KBH260POSCO홀콜': '58H260',
#  'KBH261SK콜': '58H261',
#  'KBH262SK풋': '58H262',
#  'KBH263SK바이오콜': '58H263',
#  'KBH264SK바이오콜': '58H264',
#  'KBH265SK스퀘어콜': '58H265',
#  'KBH266SK이노콜': '58H266',
#  'KBH267SK이노풋': '58H267',
#  'KBH268SK하이닉콜': '58H268',
#  'KBH269SK하이닉콜': '58H269',
#  'KBH270SK하이닉풋': '58H270',
#  'KBH271금호석유콜': '58H271',
#  'KBH272금호석유콜': '58H272',
#  'KBH273금호석유풋': '58H273',
#  'KBH274기아콜': '58H274',
#  'KBH275기아풋': '58H275',
#  'KBH276두산중공콜': '58H276',
#  'KBH277두산중공풋': '58H277',
#  'KBH278두산퓨얼콜': '58H278',
#  'KBH279삼성SDI콜': '58H279',
#  'KBH280삼성SDI콜': '58H280',
#  'KBH281삼성SDI풋': '58H281',
#  'KBH282삼성물산콜': '58H282',
#  'KBH283삼성물산풋': '58H283',
#  'KBH284삼성엔지콜': '58H284',
#  'KBH285삼성전기콜': '58H285',
#  'KBH286삼성전자콜': '58H286',
#  'KBH287삼성전자콜': '58H287',
#  'KBH288삼성전자콜': '58H288',
#  'KBH289삼성전자콜': '58H289',
#  'KBH290셀트리온콜': '58H290',
#  'KBH291셀트리온콜': '58H291',
#  'KBH292셀트리온콜': '58H292',
#  'KBH293셀트리온풋': '58H293',
#  'KBH294셀트제약콜': '58H294',
#  'KBH295셀트제약콜': '58H295',
#  'KBH296셀트헬스콜': '58H296',
#  'KBH297셀트헬스콜': '58H297',
#  'KBH298셀트헬스풋': '58H298',
#  'KBH299신한지주콜': '58H299',
#  'KBH300신한지주콜': '58H300',
#  'KBH301신한지주풋': '58H301',
#  'KBH302아모레콜': '58H302',
#  'KBH303아모레풋': '58H303',
#  'KBH304NC소프트콜': '58H304',
#  'KBH305NC소프트콜': '58H305',
#  'KBH306NC소프트풋': '58H306',
#  'KBH307카카오콜': '58H307',
#  'KBH308카카오콜': '58H308',
#  'KBH309카카오콜': '58H309',
#  'KBH310카카오풋': '58H310',
#  'KBH311카카뱅크콜': '58H311',
#  'KBH312카카뱅크콜': '58H312',
#  'KBH313카카뱅크풋': '58H313',
#  'KBH314카카페이콜': '58H314',
#  'KBH315카카페이콜': '58H315',
#  'KBH316크래프톤콜': '58H316',
#  'KBH317크래프톤콜': '58H317',
#  'KBH318포스코케콜': '58H318',
#  'KBH319포스코케콜': '58H319',
#  'KBH320하나금융콜': '58H320',
#  'KBH321하나금융콜': '58H321',
#  'KBH322하나금융풋': '58H322',
#  'KBH323하이브콜': '58H323',
#  'KBH324하이브콜': '58H324',
#  'KBH325한국전력콜': '58H325',
#  'KBH327한화솔루콜': '58H327',
#  'KBH328한화솔루콜': '58H328',
#  'KBH329한화솔루풋': '58H329',
#  'KBH330모비스콜': '58H330',
#  'KBH331모비스풋': '58H331',
#  'KBH332모비스콜': '58H332',
#  'KBH333현대차콜': '58H333',
#  'KBH334현대차콜': '58H334',
#  'KBH335현대차콜': '58H335',
#  'KBH336현대차풋': '58H336',
#  'KBH337DB하이텍콜': '58H337',
#  'KBH338현대상선콜': '58H338',
#  'KBH339엘지디스콜': '58H339',
#  'KBH340LG생건콜': '58H340',
#  'KBH341LG이노텍콜': '58H341',
#  'KBH342엘지전자콜': '58H342',
#  'KBH343LG화학콜': '58H343',
#  'KBH344네이버콜': '58H344',
#  'KBH345네이버콜': '58H345',
#  'KBH346POSCO홀콜': '58H346',
#  'KBH347SK콜': '58H347',
#  'KBH348SK바이오콜': '58H348',
#  'KBH349SK스퀘어콜': '58H349',
#  'KBH350SK아이이콜': '58H350',
#  'KBH351SK이노콜': '58H351',
#  'KBH352SK하이닉콜': '58H352',
#  'KBH353금호석유콜': '58H353',
#  'KBH354기아콜': '58H354',
#  'KBH357삼성SDI콜': '58H357',
#  'KBH358삼성물산콜': '58H358',
#  'KBH359삼성엔지콜': '58H359',
#  'KBH360삼성전자콜': '58H360',
#  'KBH361삼성전자콜': '58H361',
#  'KBH362삼성전자콜': '58H362',
#  'KBH363삼성전자콜': '58H363',
#  'KBH364삼성전자풋': '58H364',
#  'KBH365셀트리온콜': '58H365',
#  'KBH366셀트리온콜': '58H366',
#  'KBH367셀트리온콜': '58H367',
#  'KBH368셀트제약콜': '58H368',
#  'KBH370셀트헬스콜': '58H370',
#  'KBH371셀트헬스콜': '58H371',
#  'KBH372신한지주콜': '58H372',
#  'KBH373아모레콜': '58H373',
#  'KBH374아모레콜': '58H374',
#  'KBH375NC소프트콜': '58H375',
#  'KBH376NC소프트콜': '58H376',
#  'KBH377카카오콜': '58H377',
#  'KBH378카카오콜': '58H378',
#  'KBH379카카오콜': '58H379',
#  'KBH380카카뱅크콜': '58H380',
#  'KBH381카카페이콜': '58H381',
#  'KBH382크래프톤콜': '58H382',
#  'KBH383크래프톤콜': '58H383',
#  'KBH384포스코케콜': '58H384',
#  'KBH385하나금융콜': '58H385',
#  'KBH386하이브콜': '58H386',
#  'KBH387하이브콜': '58H387',
#  'KBH388한국전력콜': '58H388',
#  'KBH389한화솔루콜': '58H389',
#  'KBH390한화솔루콜': '58H390',
#  'KBH391모비스콜': '58H391',
#  'KBH392현대차콜': '58H392',
#  'KBH393엘지디스콜': '58H393',
#  'KBH394엘지디스콜': '58H394',
#  'KBH395엘지디스풋': '58H395',
#  'KBH396네이버콜': '58H396',
#  'KBH397네이버콜': '58H397',
#  'KBH398네이버풋': '58H398',
#  'KBH399POSCO홀콜': '58H399',
#  'KBH400SK바이오콜': '58H400',
#  'KBH401SK하이닉콜': '58H401',
#  'KBH402금호석유콜': '58H402',
#  'KBH403기아콜': '58H403',
#  'KBH405삼성SDI콜': '58H405',
#  'KBH406삼성물산콜': '58H406',
#  'KBH407삼성엔지콜': '58H407',
#  'KBH408삼성전기콜': '58H408',
#  'KBH409삼성전자콜': '58H409',
#  'KBH410삼성전자콜': '58H410',
#  'KBH411삼성전자콜': '58H411',
#  'KBH412셀트리온콜': '58H412',
#  'KBH413셀트리온콜': '58H413',
#  'KBH414셀트리온풋': '58H414',
#  'KBH416셀트제약콜': '58H416',
#  'KBH417셀트헬스콜': '58H417',
#  'KBH418셀트헬스풋': '58H418',
#  'KBH419아모레콜': '58H419',
#  'KBH420NC소프트콜': '58H420',
#  'KBH421NC소프트풋': '58H421',
#  'KBH422카카오콜': '58H422',
#  'KBH423카카오풋': '58H423',
#  'KBH424카카뱅크콜': '58H424',
#  'KBH425크래프톤콜': '58H425',
#  'KBH426포스코케콜': '58H426',
#  'KBH427하나금융콜': '58H427',
#  'KBH428하이브콜': '58H428',
#  'KBH429한화솔루콜': '58H429',
#  'KBH430한화솔루콜': '58H430',
#  'KBH431모비스콜': '58H431',
#  'KBH432현대차콜': '58H432',
#  'KBH433엘지디스콜': '58H433',
#  'KBH434엘지전자콜': '58H434',
#  'KBH435네이버콜': '58H435',
#  'KBH436SK하이닉콜': '58H436',
#  'KBH437기아콜': '58H437',
#  'KBH438삼성SDI콜': '58H438',
#  'KBH439삼성전자콜': '58H439',
#  'KBH440삼성전자콜': '58H440',
#  'KBH441삼성전자풋': '58H441',
#  ...}

# %%
import json

# %%
#저장하기
# save_file = open('data/stock2code.json','w') #방법1
json.dump(dct, open('data/stock2code.json','w')) #방법2

# %%
# 불러오기
stock2code = json.load(open('data/stock2code.json','r'))

# %%
stock2code['NAVER']
# Out:
# '035420'

# %% [markdown]
# ## YahooFinance

# %%
# !pip install yahoo-finance
import yfinance as yf
# Out:
# Requirement already satisfied: yahoo-finance in c:\users\g4560\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: simplejson in c:\users\g4560\anaconda3\lib\site-packages (from yahoo-finance) (3.17.6)
# Requirement already satisfied: pytz in c:\users\g4560\anaconda3\lib\site-packages (from yahoo-finance) (2021.3)

# %%
pip install --upgrade yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\g4560\anaconda3\lib\site-packages (0.1.70)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy>=1.15 in c:\users\g4560\anaconda3\lib\site-packages (from yfinance) (1.22.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\g4560\anaconda3\lib\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\g4560\anaconda3\lib\site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: requests>=2.26 in c:\users\g4560\anaconda3\lib\site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\g4560\anaconda3\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\g4560\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\g4560\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\g4560\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.7)

# %%
df_amzn = yf.download('AMZN', 
           start=  '2018-01-01',
           end='2020-12-31',
           progress=False,  #진행상황 표시 여부 
           auto_adjust = False,  #False로 하면 Adjust 전의 종가와 후의 종가 모두 확인 가능
           actions='inline')
df_amzn
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-02  1172.000000  1190.000000  1170.510010  1189.010010  1189.010010
# 2018-01-03  1188.300049  1205.489990  1188.300049  1204.199951  1204.199951
# 2018-01-04  1205.000000  1215.869995  1204.660034  1209.589966  1209.589966
# 2018-01-05  1217.510010  1229.140015  1210.000000  1229.140015  1229.140015
# 2018-01-08  1236.000000  1253.079956  1232.030029  1246.869995  1246.869995
# ...                 ...          ...          ...          ...          ...
# 2020-12-23  3205.000000  3210.129883  3184.169922  3185.270020  3185.270020
# 2020-12-24  3193.899902  3202.000000  3169.000000  3172.689941  3172.689941
# 2020-12-28  3194.000000  3304.000000  3172.689941  3283.959961  3283.959961
# 2020-12-29  3309.939941  3350.649902  3281.219971  3322.000000  3322.000000
# 2020-12-30  3341.000000  3342.100098  3282.469971  3285.850098  3285.850098
#
#              Volume  Dividends  Stock Splits
# Date
# 2018-01-02  2694500          0             0
# 2018-01-03  3108800          0             0
# 2018-01-04  3022100          0             0
# 2018-01-05  3544700          0             0
# 2018-01-08  4279500          0             0
# ...             ...        ...           ...
# 2020-12-23  2093800          0             0
# 2020-12-24  1451900          0             0
# 2020-12-28  5686800          0             0
# 2020-12-29  4872900          0             0
# 2020-12-30  3209300          0             0
#
# [755 rows x 8 columns]

# %%
dir(amzn) #python 내장함수 dir는 사용할 수 있는 method를 보여줌
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_analysis',
#  '_balancesheet',
#  '_base_url',
#  '_calendar',
#  '_cashflow',
#  '_download_options',
#  '_earnings',
#  '_expirations',
#  '_financials',
#  '_fundamentals',
#  '_get_fundamentals',
#  '_history',
#  '_info',
#  '_institutional_holders',
#  '_isin',
#  '_major_holders',
#  '_mutualfund_holders',
#  '_news',
#  '_options2df',
#  '_recommendations',
#  '_scrape_url',
#  '_shares',
#  '_sustainability',
#  'actions',
#  'analysis',
#  'balance_sheet',
#  'balancesheet',
#  'calendar',
#  'cashflow',
#  'dividends',
#  'earnings',
#  'financials',
#  'get_actions',
#  'get_analysis',
#  'get_balance_sheet',
#  'get_balancesheet',
#  'get_calendar',
#  'get_cashflow',
#  'get_dividends',
#  'get_earnings',
#  'get_financials',
#  'get_info',
#  'get_institutional_holders',
#  'get_isin',
#  'get_major_holders',
#  'get_mutualfund_holders',
#  'get_news',
#  'get_recommendations',
#  'get_shares',
#  'get_splits',
#  'get_sustainability',
#  'history',
#  'info',
#  'institutional_holders',
#  'isin',
#  'major_holders',
#  'mutualfund_holders',
#  'news',
#  'option_chain',
#  'options',
#  'quarterly_balance_sheet',
#  'quarterly_balancesheet',
#  'quarterly_cashflow',
#  'quarterly_earnings',
#  'quarterly_financials',
#  'recommendations',
#  'session',
#  'shares',
#  'splits',
#  'stats',
#  'sustainability',
#  'ticker']

# %%
amzn = yf.Ticker('AMZN')
amzn.history(period='6mo', interval = '5d')  #6개월전부터 현재까지, 5일 간격으로
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2021-10-07  3291.540039  3325.750000  3283.060059  3302.429932   2409100
# 2021-10-12  3257.000000  3267.530029  3236.280029  3247.330078   1819600
# 2021-10-22  3421.000000  3429.840088  3331.300049  3335.550049   3139100
# 2021-10-27  3388.000000  3437.000000  3371.449951  3392.489990   2702200
# 2021-11-01  3361.800049  3375.860107  3292.020020  3318.110107   3608900
# 2021-11-11  3513.000000  3543.239990  3467.469971  3472.500000   2264400
# 2021-11-16  3539.000000  3576.500000  3525.149902  3540.699951   2217100
# 2021-11-26  3602.100098  3633.500000  3504.149902  3504.560059   2991300
# 2021-12-01  3545.000000  3559.879883  3441.600098  3443.719971   3745800
# 2021-12-06  3393.000000  3473.909912  3338.689941  3427.370117   3443000
# 2021-12-16  3467.370117  3483.320068  3363.209961  3377.419922   3043800
#  'currentPrice': 3175.12,
#  'earningsGrowth': 0.975,
#  'currentRatio': 1.136,
#  'returnOnAssets': 0.041929998,
#  'numberOfAnalystOpinions': 54,
#  'targetMeanPrice': 4073.96,
#  'debtToEquity': 100.864,
#  'returnOnEquity': 0.28806,
#  'targetHighPrice': 5000,
#  'totalCash': 96048996352,
#  'totalDebt': 139438997504,
#  'totalRevenue': 469822013440,
#  'totalCashPerShare': 188.759,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 928.502,
#  'quickRatio': 0.905,
#  'recommendationMean': 1.7,
#  'exchange': 'NMS',
#  'shortName': 'Amazon.com, Inc.',
#  'longName': 'Amazon.com, Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'AMZN',
#  'messageBoardId': 'finmb_18749',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 3.646,
#  'beta3Year': None,
#  'enterpriseToEbitda': 28.947,
#  '52WeekChange': -0.037638307,
#  'morningStarRiskRating': None,
#  'forwardEps': 72.66,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 508844000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 271.601,
#  'sharesShort': 4229483,
#  'sharesPercentSharesOut': 0.0083,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.60342,
#  'netIncomeToCommon': 33364000768,
#  'trailingEps': 64.81,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.09371829,
#  'priceToBook': 11.690384,
#  'heldPercentInsiders': 0.09884,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1640908800,
#  'shortRatio': 1.19,
#  'sharesShortPreviousMonthDate': 1644883200,
#  'floatShares': 457995588,
#  'beta': 1.119607,
#  'enterpriseValue': 1712959389696,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 936230400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.983,
#  'priceToSalesTrailing12Months': 3.4388359,
#  'dateShortInterest': 1647302400,
#  'pegRatio': 1.99,
#  'ytdReturn': None,
#  'forwardPE': 43.69832,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0097,
#  'sharesShortPriorMonth': 4315526,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 3281.1,
#  'regularMarketOpen': 3233.01,
#  'twoHundredDayAverage': 3326.1953,
#  'trailingAnnualDividendYield': 0,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 3243.9875,
#  'navPrice': None,
#  'averageDailyVolume10Day': 2937870,
#  'regularMarketPreviousClose': 3281.1,
#  'fiftyDayAverage': 3078.849,
#  'trailingAnnualDividendRate': 0,
#  'open': 3233.01,
#  'toCurrency': None,
#  'averageVolume10days': 2937870,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 3146.03,
#  'currency': 'USD',
#  'trailingPE': 48.991207,
#  'regularMarketVolume': 3952788,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1615640788992,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 3922044,
#  'dayLow': 3146.03,
#  'ask': 3162,
#  'askSize': 800,
#  'volume': 3952788,
#  'fiftyTwoWeekHigh': 3773.08,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 2671.45,
#  'bid': 3154,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 900,
#  'dayHigh': 3243.9875,
#  'regularMarketPrice': 3175.12,
#  'preMarketPrice': 3233.5,
#  'logo_url': 'https://logo.clearbit.com/amazon.com',
#  'trailingPegRatio': 3.0603}

# %%
amzn.get_balancesheet()
# Out:
#                              2021-12-31    2020-12-31    2019-12-31  \
# Intangible Assets          5.107000e+09  4.981000e+09  4.049000e+09
# Capital Surplus            5.553800e+10  4.286500e+10  3.365800e+10
# Total Liab                 2.823040e+11  2.277910e+11  1.631880e+11
# Total Stockholder Equity   1.382450e+11  9.340400e+10  6.206000e+10
# Other Current Liab         1.802700e+10  1.526700e+10  1.220200e+10
# Total Assets               4.205490e+11  3.211950e+11  2.252480e+11
# Common Stock               5.000000e+06  5.000000e+06  5.000000e+06
# Other Current Assets       2.420000e+08  2.330000e+08  2.760000e+08
# Retained Earnings          8.591500e+10  5.255100e+10  3.122000e+10
# Other Liab                 1.744300e+10  1.361700e+10  1.217100e+10
# Good Will                  1.537100e+10  1.501700e+10  1.475400e+10
# Treasury Stock            -3.213000e+09 -2.017000e+09 -2.823000e+09
# Other Assets               1.812500e+10  1.209700e+10  1.009600e+10
# Cash                       3.622000e+10  4.212200e+10  3.609200e+10
# Total Current Liabilities  1.422660e+11  1.263850e+11  8.781200e+10
# Short Long Term Debt       1.687000e+09  1.266000e+09  1.305000e+09
# Other Stockholder Equity  -1.376000e+09 -1.800000e+08 -9.860000e+08
# Property Plant Equipment   2.163630e+11  1.506670e+11  9.784600e+10
# Total Current Assets       1.615800e+11  1.327330e+11  9.633400e+10
# Long Term Investments      4.003000e+09  5.700000e+09  2.169000e+09
# Net Tangible Assets        1.177670e+11  7.340600e+10  4.325700e+10
# Short Term Investments     5.982900e+10  4.227400e+10  1.892900e+10
# Net Receivables            3.264900e+10  2.430900e+10  2.054000e+10
# Long Term Debt             5.494400e+10  3.521600e+10  2.341400e+10
# Inventory                  3.264000e+10  2.379500e+10  2.049700e+10
# Accounts Payable           7.866400e+10  7.253900e+10  4.718300e+10
#
#                              2018-12-31
# Intangible Assets          4.110000e+09
# Capital Surplus            2.679100e+10
# Total Liab                 1.190990e+11
# Total Stockholder Equity   4.354900e+10
# Other Current Liab         9.959000e+09
# Total Assets               1.626480e+11
# Common Stock               5.000000e+06
# Other Current Assets       4.180000e+08
# Retained Earnings          1.962500e+10
# Other Liab                 1.756300e+10
# Good Will                  1.454800e+10
# Treasury Stock            -2.872000e+09
# Other Assets               6.370000e+09
# Cash                       3.175000e+10
# Total Current Liabilities  6.839100e+10
# Short Long Term Debt       1.371000e+09
# Other Stockholder Equity  -1.035000e+09
# Property Plant Equipment   6.179700e+10
# Total Current Assets       7.510100e+10
# Long Term Investments      7.220000e+08
# Net Tangible Assets        2.489100e+10
# Short Term Investments     9.500000e+09
# Net Receivables            1.625900e+10
# Long Term Debt             2.349500e+10
# Inventory                  1.717400e+10
# Accounts Payable           3.819200e+10

# %%
amzn.get_balancesheet().iloc[0:6, :]  # 재무상태표
# Out:
#                             2021-12-31    2020-12-31    2019-12-31  \
# Intangible Assets         5.107000e+09  4.981000e+09  4.049000e+09
# Capital Surplus           5.553800e+10  4.286500e+10  3.365800e+10
# Total Liab                2.823040e+11  2.277910e+11  1.631880e+11
# Total Stockholder Equity  1.382450e+11  9.340400e+10  6.206000e+10
# Other Current Liab        1.802700e+10  1.526700e+10  1.220200e+10
# Total Assets              4.205490e+11  3.211950e+11  2.252480e+11
#
#                             2018-12-31
# Intangible Assets         4.110000e+09
# Capital Surplus           2.679100e+10
# Total Liab                1.190990e+11
# Total Stockholder Equity  4.354900e+10
# Other Current Liab        9.959000e+09
# Total Assets              1.626480e+11

# %%
yf.Ticker('005930.KS').info
# Out:
# {'zip': '443-742',
#  'sector': 'Technology',
#  'longBusinessSummary': 'Samsung Electronics Co., Ltd. engages in the consumer electronics, information technology and mobile communications, and device solutions businesses worldwide. It offers digital TVs, monitors, air conditioners, refrigerators, mobile phones, communication systems, and computers; semiconductor products, such as memory, foundry, and system LSI; and display products comprising LCD and OLED panels, as well as connected car systems, audio and visual products, enterprise automation solutions, and connected services. The company is also involved in the technology and venture capital investment businesses; manufacture of semiconductor equipment and components; and provision of repair services for electronic devices. In addition, it provides medical equipment; software development and supply; toll processing of semiconductors and display panels; general logistics agency, financing, marketing, consulting, and AI technology and cloud services; enterprise automation solutions and connected services; and digital advertising platforms. Further, the company offers mobile payment services; and designs and develops software products. It serves retail, hospitality, finance, transportation, education, government, and healthcare industries. Samsung Electronics Co., Ltd. was founded in 1938 and is based in Suwon, South Korea.',
#  'city': 'Suwon-si',
#  'phone': '82 31 200 1114',
#  'country': 'South Korea',
#  'companyOfficers': [],
#  'website': 'https://www.samsung.com',
#  'maxAge': 1,
#  'address1': '129, Samsung-ro',
#  'industry': 'Consumer Electronics',
#  'address2': 'Yeongtong-gu',
#  'ebitdaMargins': 0.30337998,
#  'profitMargins': 0.14035,
#  'grossMargins': 0.40483,
#  'operatingCashflow': 65105446305792,
#  'revenueGrowth': 0.244,
#  'operatingMargins': 0.18466999,
#  'ebitda': 84827483144192,
#  'targetLowPrice': 70000,
#  'recommendationKey': 'buy',
#  'grossProfits': 113193457000000,
#  'freeCashflow': 10735831744512,
#  'targetMedianPrice': 100500,
#  'currentPrice': 68200,
#  'earningsGrowth': 0.653,
#  'currentRatio': 2.476,
#  'returnOnAssets': 0.08019,
#  'numberOfAnalystOpinions': 38,
#  'targetMeanPrice': 99184,
#  'debtToEquity': 6.032,
#  'returnOnEquity': 0.13741,
#  'targetHighPrice': 130000,
#  'totalCash': 124150190440448,
#  'totalDebt': 18392148869120,
#  'totalRevenue': 279604803665920,
#  'totalCashPerShare': 18277.086,
#  'financialCurrency': 'KRW',
#  'revenuePerShare': 41162.723,
#  'quickRatio': 1.922,
#  'recommendationMean': 1.8,
#  'exchange': 'KSC',
#  'shortName': 'SamsungElec',
#  'longName': 'Samsung Electronics Co., Ltd.',
#  'exchangeTimezoneName': 'Asia/Seoul',
#  'exchangeTimezoneShortName': 'KST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '32400000',
#  'quoteType': 'EQUITY',
#  'symbol': '005930.KS',
#  'messageBoardId': 'finmb_91868',
#  'market': 'kr_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 1.334,
#  'beta3Year': None,
#  'enterpriseToEbitda': 4.397,
#  '52WeekChange': -0.19126326,
#  'morningStarRiskRating': None,
#  'forwardEps': None,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 5969780224,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': None,
#  'sharesShort': None,
#  'sharesPercentSharesOut': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.40273,
#  'netIncomeToCommon': 39243791466496,
#  'trailingEps': None,
#  'lastDividendValue': 361,
#  'SandP52WeekChange': 0.09371829,
#  'priceToBook': None,
#  'heldPercentInsiders': 0.19307,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1640908800,
#  'shortRatio': None,
#  'sharesShortPreviousMonthDate': None,
#  'floatShares': 5535278245,
#  'beta': 0.93209,
#  'enterpriseValue': 372956907700224,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1526428800,
#  'lastSplitFactor': '50:1',
#  'legalType': None,
#  'lastDividendDate': 1640736000,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.653,
#  'priceToSalesTrailing12Months': 1.6376963,
#  'dateShortInterest': None,
#  'pegRatio': 0.38,
#  'ytdReturn': None,
#  'forwardPE': None,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': None,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 68500,
#  'regularMarketOpen': 68500,
#  'twoHundredDayAverage': 74978,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0.25,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 68500,
#  'navPrice': None,
#  'averageDailyVolume10Day': 15342472,
#  'regularMarketPreviousClose': 68500,
#  'fiftyDayAverage': 71822,
#  'trailingAnnualDividendRate': None,
#  'open': 68500,
#  'toCurrency': None,
#  'averageVolume10days': 15342472,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 1444,
#  'exDividendDate': 1640736000,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 68100,
#  'currency': 'KRW',
#  'regularMarketVolume': 8498849,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 457907736936448,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 10933664,
#  'dayLow': 68100,
#  'ask': 68200,
#  'askSize': 0,
#  'volume': 8498849,
#  'fiftyTwoWeekHigh': 85700,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 2.77,
#  'fiftyTwoWeekLow': 68100,
#  'bid': 68100,
#  'tradeable': False,
#  'dividendYield': 0.0209,
#  'bidSize': 0,
#  'dayHigh': 68500,
#  'regularMarketPrice': 68200,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/samsung.com',
#  'trailingPegRatio': 1.3935}

# %%
yf.Ticker('005930.KS').get_balancesheet()
# Out:
#                                     2021-12-31    2020-12-31    2019-12-31  \
# Intangible Assets                 1.415508e+13  1.242347e+13  1.371229e+13
# Capital Surplus                   4.403893e+12  4.403893e+12  4.403893e+12
# Total Liab                        1.217212e+14  1.022877e+14  8.968408e+13
# Total Stockholder Equity          2.962377e+14  2.676703e+14  2.549155e+14
# Minority Interest                 8.662234e+12  8.277685e+12  7.964949e+12
# Deferred Long Term Liab           2.369100e+11  3.713910e+11  7.407740e+11
# Other Current Liab                3.171799e+13  2.426526e+13  2.046536e+13
# Total Assets                      4.266212e+14  3.782357e+14  3.525645e+14
# Common Stock                      8.975140e+11  8.975140e+11  8.975140e+11
# Other Current Assets              5.081665e+12  4.683894e+12  4.122410e+12
# Retained Earnings                 2.930648e+14  2.710682e+14  2.545829e+14
# Other Liab                        3.022971e+13  2.373550e+13  2.272883e+13
# Good Will                         5.844259e+12  5.673642e+12  6.250439e+12
# Treasury Stock                   -2.128473e+12 -8.699287e+12 -4.968829e+12
# Other Assets                      1.410667e+13  1.111517e+13  1.382970e+13
# Cash                              3.903142e+13  2.938258e+13  2.688600e+13
# Total Current Liabilities         8.811713e+13  7.560435e+13  6.378276e+13
# Deferred Long Term Asset Charges  4.261214e+12  4.275000e+12  4.505049e+12
# Short Long Term Debt              5.180650e+11  5.318000e+09  4.102200e+10
# Other Stockholder Equity         -2.128473e+12 -8.699287e+12 -4.968829e+12
# Property Plant Equipment          1.499285e+14  1.289529e+14  1.198255e+14
# Total Current Assets              2.181632e+14  1.982156e+14  1.813853e+14
# Long Term Investments             2.442343e+13  2.185496e+13  1.756133e+13
# Net Tangible Assets               2.762384e+14  2.495732e+14  2.349527e+14
# Short Term Investments            8.507802e+13  9.519881e+13  8.016627e+13
# Net Receivables                   4.521067e+13  3.456960e+13  3.931046e+13
# Long Term Debt                    5.097320e+11  9.481370e+11  9.752980e+11
# Inventory                         4.138440e+13  3.204314e+13  2.676646e+13
# Accounts Payable                  1.345335e+13  9.739222e+12  8.718222e+12
#
#                                     2018-12-31
# Intangible Assets                 8.353186e+12
# Capital Surplus                   4.403893e+12
# Total Liab                        9.160407e+13
# Total Stockholder Equity          2.400690e+14
# Minority Interest                 7.684184e+12
# Deferred Long Term Liab           7.047340e+11
# Other Current Liab                2.664186e+13
# Total Assets                      3.393572e+14
# Common Stock                      8.975140e+11
# Other Current Assets              3.751208e+12
# Retained Earnings                 2.426990e+14
# Other Liab                        2.147550e+13
# Good Will                         5.833678e+12
# Treasury Stock                   -7.931370e+12
# Other Assets                      1.942794e+13
# Cash                              3.034050e+13
# Total Current Liabilities         6.908151e+13
# Deferred Long Term Asset Charges  5.468002e+12
# Short Long Term Debt              2.231900e+10
# Other Stockholder Equity         -7.931370e+12
# Property Plant Equipment          1.154167e+14
# Total Current Assets              1.746974e+14
# Long Term Investments             1.562829e+13
# Net Tangible Assets               2.258821e+14
# Short Term Investments            6.853443e+13
# Net Receivables                   3.694847e+13
# Long Term Debt                    9.969350e+11
# Inventory                         2.898470e+13
# Accounts Payable                  8.479916e+12

# %%
# 한국주식
yf.Ticker('005930.KS').info
# Out:
# {'zip': '443-742',
#  'sector': 'Technology',
#  'longBusinessSummary': 'Samsung Electronics Co., Ltd. engages in the consumer electronics, information technology and mobile communications, and device solutions businesses worldwide. It offers digital TVs, monitors, air conditioners, refrigerators, mobile phones, communication systems, and computers; semiconductor products, such as memory, foundry, and system LSI; and display products comprising LCD and OLED panels, as well as connected car systems, audio and visual products, enterprise automation solutions, and connected services. The company is also involved in the technology and venture capital investment businesses; manufacture of semiconductor equipment and components; and provision of repair services for electronic devices. In addition, it provides medical equipment; software development and supply; toll processing of semiconductors and display panels; general logistics agency, financing, marketing, consulting, and AI technology and cloud services; enterprise automation solutions and connected services; and digital advertising platforms. Further, the company offers mobile payment services; and designs and develops software products. It serves retail, hospitality, finance, transportation, education, government, and healthcare industries. Samsung Electronics Co., Ltd. was founded in 1938 and is based in Suwon, South Korea.',
#  'city': 'Suwon-si',
#  'phone': '82 31 200 1114',
#  'country': 'South Korea',
#  'companyOfficers': [],
#  'website': 'https://www.samsung.com',
#  'maxAge': 1,
#  'address1': '129, Samsung-ro',
#  'industry': 'Consumer Electronics',
#  'address2': 'Yeongtong-gu',
#  'ebitdaMargins': 0.30337998,
#  'profitMargins': 0.14035,
#  'grossMargins': 0.40483,
#  'operatingCashflow': 65105446305792,
#  'revenueGrowth': 0.244,
#  'operatingMargins': 0.18466999,
#  'ebitda': 84827483144192,
#  'targetLowPrice': 70000,
#  'recommendationKey': 'buy',
#  'grossProfits': 113193457000000,
#  'freeCashflow': 10735831744512,
#  'targetMedianPrice': 100500,
#  'currentPrice': 68200,
#  'earningsGrowth': 0.653,
#  'currentRatio': 2.476,
#  'returnOnAssets': 0.08019,
#  'numberOfAnalystOpinions': 38,
#  'targetMeanPrice': 99184,
#  'debtToEquity': 6.032,
#  'returnOnEquity': 0.13741,
#  'targetHighPrice': 130000,
#  'totalCash': 124150190440448,
#  'totalDebt': 18392148869120,
#  'totalRevenue': 279604803665920,
#  'totalCashPerShare': 18277.086,
#  'financialCurrency': 'KRW',
#  'revenuePerShare': 41162.723,
#  'quickRatio': 1.922,
#  'recommendationMean': 1.8,
#  'exchange': 'KSC',
#  'shortName': 'SamsungElec',
#  'longName': 'Samsung Electronics Co., Ltd.',
#  'exchangeTimezoneName': 'Asia/Seoul',
#  'exchangeTimezoneShortName': 'KST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '32400000',
#  'quoteType': 'EQUITY',
#  'symbol': '005930.KS',
#  'messageBoardId': 'finmb_91868',
#  'market': 'kr_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 1.334,
#  'beta3Year': None,
#  'enterpriseToEbitda': 4.397,
#  '52WeekChange': -0.19126326,
#  'morningStarRiskRating': None,
#  'forwardEps': None,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 5969780224,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': None,
#  'sharesShort': None,
#  'sharesPercentSharesOut': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.40273,
#  'netIncomeToCommon': 39243791466496,
#  'trailingEps': None,
#  'lastDividendValue': 361,
#  'SandP52WeekChange': 0.09371829,
#  'priceToBook': None,
#  'heldPercentInsiders': 0.19307,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1640908800,
#  'shortRatio': None,
#  'sharesShortPreviousMonthDate': None,
#  'floatShares': 5535278245,
#  'beta': 0.93209,
#  'enterpriseValue': 372956907700224,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1526428800,
#  'lastSplitFactor': '50:1',
#  'legalType': None,
#  'lastDividendDate': 1640736000,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.653,
#  'priceToSalesTrailing12Months': 1.6376963,
#  'dateShortInterest': None,
#  'pegRatio': 0.38,
#  'ytdReturn': None,
#  'forwardPE': None,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': None,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 68500,
#  'regularMarketOpen': 68500,
#  'twoHundredDayAverage': 74978,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0.25,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 68500,
#  'navPrice': None,
#  'averageDailyVolume10Day': 15342472,
#  'regularMarketPreviousClose': 68500,
#  'fiftyDayAverage': 71822,
#  'trailingAnnualDividendRate': None,
#  'open': 68500,
#  'toCurrency': None,
#  'averageVolume10days': 15342472,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 1444,
#  'exDividendDate': 1640736000,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 68100,
#  'currency': 'KRW',
#  'regularMarketVolume': 8652303,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 457907736936448,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 10933664,
#  'dayLow': 68100,
#  'ask': 68200,
#  'askSize': 0,
#  'volume': 8652303,
#  'fiftyTwoWeekHigh': 85700,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 2.77,
#  'fiftyTwoWeekLow': 68100,
#  'bid': 68100,
#  'tradeable': False,
#  'dividendYield': 0.0209,
#  'bidSize': 0,
#  'dayHigh': 68500,
#  'regularMarketPrice': 68200,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/samsung.com',
#  'trailingPegRatio': 1.3935}

# %%
yf.Ticker('005930.KS').get_balancesheet()
# Out:
#                                     2021-12-31    2020-12-31    2019-12-31  \
# Intangible Assets                 1.415508e+13  1.242347e+13  1.371229e+13
# Capital Surplus                   4.403893e+12  4.403893e+12  4.403893e+12
# Total Liab                        1.217212e+14  1.022877e+14  8.968408e+13
# Total Stockholder Equity          2.962377e+14  2.676703e+14  2.549155e+14
# Minority Interest                 8.662234e+12  8.277685e+12  7.964949e+12
# Deferred Long Term Liab           2.369100e+11  3.713910e+11  7.407740e+11
# Other Current Liab                3.171799e+13  2.426526e+13  2.046536e+13
# Total Assets                      4.266212e+14  3.782357e+14  3.525645e+14
# Common Stock                      8.975140e+11  8.975140e+11  8.975140e+11
# Other Current Assets              5.081665e+12  4.683894e+12  4.122410e+12
# Retained Earnings                 2.930648e+14  2.710682e+14  2.545829e+14
# Other Liab                        3.022971e+13  2.373550e+13  2.272883e+13
# Good Will                         5.844259e+12  5.673642e+12  6.250439e+12
# Treasury Stock                   -2.128473e+12 -8.699287e+12 -4.968829e+12
# Other Assets                      1.410667e+13  1.111517e+13  1.382970e+13
# Cash                              3.903142e+13  2.938258e+13  2.688600e+13
# Total Current Liabilities         8.811713e+13  7.560435e+13  6.378276e+13
# Deferred Long Term Asset Charges  4.261214e+12  4.275000e+12  4.505049e+12
# Short Long Term Debt              5.180650e+11  5.318000e+09  4.102200e+10
# Other Stockholder Equity         -2.128473e+12 -8.699287e+12 -4.968829e+12
# Property Plant Equipment          1.499285e+14  1.289529e+14  1.198255e+14
# Total Current Assets              2.181632e+14  1.982156e+14  1.813853e+14
# Long Term Investments             2.442343e+13  2.185496e+13  1.756133e+13
# Net Tangible Assets               2.762384e+14  2.495732e+14  2.349527e+14
# Short Term Investments            8.507802e+13  9.519881e+13  8.016627e+13
# Net Receivables                   4.521067e+13  3.456960e+13  3.931046e+13
# Long Term Debt                    5.097320e+11  9.481370e+11  9.752980e+11
# Inventory                         4.138440e+13  3.204314e+13  2.676646e+13
# Accounts Payable                  1.345335e+13  9.739222e+12  8.718222e+12
#
#                                     2018-12-31
# Intangible Assets                 8.353186e+12
# Capital Surplus                   4.403893e+12
# Total Liab                        9.160407e+13
# Total Stockholder Equity          2.400690e+14
# Minority Interest                 7.684184e+12
# Deferred Long Term Liab           7.047340e+11
# Other Current Liab                2.664186e+13
# Total Assets                      3.393572e+14
# Common Stock                      8.975140e+11
# Other Current Assets              3.751208e+12
# Retained Earnings                 2.426990e+14
# Other Liab                        2.147550e+13
# Good Will                         5.833678e+12
# Treasury Stock                   -7.931370e+12
# Other Assets                      1.942794e+13
# Cash                              3.034050e+13
# Total Current Liabilities         6.908151e+13
# Deferred Long Term Asset Charges  5.468002e+12
# Short Long Term Debt              2.231900e+10
# Other Stockholder Equity         -7.931370e+12
# Property Plant Equipment          1.154167e+14
# Total Current Assets              1.746974e+14
# Long Term Investments             1.562829e+13
# Net Tangible Assets               2.258821e+14
# Short Term Investments            6.853443e+13
# Net Receivables                   3.694847e+13
# Long Term Debt                    9.969350e+11
# Inventory                         2.898470e+13
# Accounts Payable                  8.479916e+12

# %% [markdown]
# ## Quandl

# %% [markdown]
# - 개인 API key 필요
#
# https://data.nasdaq.com/

# %%
# !pip install quandl
import quandl
# Out:
# Collecting quandl
#   Downloading Quandl-3.7.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\g4560\anaconda3\lib\site-packages (from quandl) (0.5.1)
# Requirement already satisfied: more-itertools in c:\users\g4560\anaconda3\lib\site-packages (from quandl) (8.10.0)
# Requirement already satisfied: six in c:\users\g4560\anaconda3\lib\site-packages (from quandl) (1.15.0)
# Requirement already satisfied: pandas>=0.14 in c:\users\g4560\anaconda3\lib\site-packages (from quandl) (1.4.2)
# Requirement already satisfied: numpy>=1.8 in c:\users\g4560\anaconda3\lib\site-packages (from quandl) (1.22.3)
# Requirement already satisfied: requests>=2.7.0 in c:\users\g4560\anaconda3\lib\site-packages (from quandl) (2.26.0)
# Requirement already satisfied: python-dateutil in c:\users\g4560\anaconda3\lib\site-packages (from quandl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\g4560\anaconda3\lib\site-packages (from pandas>=0.14->quandl) (2021.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (3.2)
# Installing collected packages: quandl
# Successfully installed quandl-3.7.0

# %%
ht_key = 'bEMZ9-XsbnJzthPjmLi2'

# %%
quandl_key = ht_key
quandl.ApiConfig.api_key = quandl_key

# %% [markdown]
# London Bullion Market Association

# %% [markdown]
# 금 : LBMA/GOLD
#
# 원유 : OPEC/ORB

# %%
df_quandl = quandl.get(dataset=['LBMA/GOLD'], start_date='2015-01-01')
df_quandl
# Out:
#             LBMA/GOLD - USD (AM)  LBMA/GOLD - USD (PM)  LBMA/GOLD - GBP (AM)  \
# Date
# 2015-01-02               1184.25               1172.00               766.406
# 2015-01-05               1192.00               1200.00               779.901
# 2015-01-06               1211.00               1210.25               797.078
# 2015-01-07               1213.75               1210.50               802.373
# 2015-01-08               1206.50               1215.50               800.969
# ...                          ...                   ...                   ...
# 2022-03-30               1917.80               1933.85              1458.300
# 2022-03-31               1924.10               1942.15              1466.930
# 2022-04-01               1933.35               1929.40              1472.440
# 2022-04-04               1927.10               1930.30              1469.030
# 2022-04-05               1929.45               1944.05              1468.700
#
#             LBMA/GOLD - GBP (PM)  LBMA/GOLD - EURO (AM)  LBMA/GOLD - EURO (PM)
# Date
# 2015-01-02               760.792                983.351                974.879
# 2015-01-05               788.022                998.911               1005.530
# 2015-01-06               797.161               1017.305               1014.715
# 2015-01-07               802.293               1023.830               1023.679
# 2015-01-08               805.874               1025.064               1030.521
# ...                          ...                    ...                    ...
# 2022-03-30              1468.570               1719.120               1732.730
# 2022-03-31              1479.530               1729.770               1751.630
# 2022-04-01              1472.900               1748.720               1746.490
# 2022-04-04              1471.850               1748.460               1756.570
# 2022-04-05              1477.090               1756.570               1772.580
#
# [1837 rows x 6 columns]

# %%
df_quandl2 = quandl.get(dataset=['OPEC/ORB'], start_date='2015-01-01')
df_quandl2
# Out:
#             OPEC/ORB - Value
# Date
# 2015-01-02             51.78
# 2015-01-05             48.87
# 2015-01-06             46.57
# 2015-01-07             44.79
# 2015-01-08             45.68
# ...                      ...
# 2022-03-30            110.46
# 2022-03-31            107.74
# 2022-04-01            104.90
# 2022-04-04            106.23
# 2022-04-05            108.05
#
# [1873 rows x 1 columns]

# %%
cpi = quandl.get(dataset='RATEINF/CPI_USA', start_date='2015-01-01')
cpi
# Out:
#               Value
# Date
# 2015-01-31  233.707
# 2015-02-28  234.722
# 2015-03-31  236.119
# 2015-04-30  236.599
# 2015-05-31  237.805
# ...             ...
# 2021-10-31  276.589
# 2021-11-30  277.948
# 2021-12-31  278.802
# 2022-01-31  281.148
# 2022-02-28  283.716
#
# [86 rows x 1 columns]

# %% [markdown]
# ## OpenDartReader

# %% [markdown]
# https://github.com/FinanceData/OpenDartReader

# %%
# !pip install opendartreader
import OpenDartReader
# Out:
# Collecting opendartreader
#   Downloading OpenDartReader-0.1.6-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\g4560\anaconda3\lib\site-packages (from opendartreader) (1.4.2)
# Requirement already satisfied: requests-file in c:\users\g4560\anaconda3\lib\site-packages (from opendartreader) (1.5.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\g4560\anaconda3\lib\site-packages (from opendartreader) (2.26.0)
# Requirement already satisfied: lxml in c:\users\g4560\anaconda3\lib\site-packages (from opendartreader) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\g4560\anaconda3\lib\site-packages (from pandas>=0.19.2->opendartreader) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\g4560\anaconda3\lib\site-packages (from pandas>=0.19.2->opendartreader) (1.22.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\g4560\anaconda3\lib\site-packages (from pandas>=0.19.2->opendartreader) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\g4560\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19.2->opendartreader) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.3.0->opendartreader) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.3.0->opendartreader) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.3.0->opendartreader) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\g4560\anaconda3\lib\site-packages (from requests>=2.3.0->opendartreader) (2.0.4)
# Installing collected packages: opendartreader
# Successfully installed opendartreader-0.1.6
